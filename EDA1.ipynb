# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/DELL/Downloads/EDA1/EDA1/Cardiotocographic.csv')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info() #gives Structural Information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.isnull().sum()   #checking for missing values
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#As 21 rows of 2126 rows are missing that is 1% approx data is missing from some of the  columns
#we have got 2 options:

# %%
#1 option: drop the rows having missing values
df1=df.dropna()

# %%
df1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB

# %%
#21 row from above data are deleted.

# %%
#option 2: we can impute those missing values using statistical operations

# %%
mean_val=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].mean()
print(mean_val)
# Out:
# LB          133.343598
# AC            0.003219
# DS            0.000003
# DP            0.000175
# MLTV          8.284887
# Width        70.429260
# Tendency      0.316371
# NSP           1.304507
# dtype: float64

# %%
df_imp=df.fillna(mean_val)

# %%
df_imp
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df_imp.isnull().sum()  #no missing values
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#similarly we can do this with median
med_val=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].median()
print(med_val)
# Out:
# LB          133.000000
# AC            0.001634
# DS            0.000000
# DP            0.000000
# MLTV          7.400000
# Width        67.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
df_imp2=df.fillna(med_val)

# %%
df_imp2
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df_imp2.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#this checks for unique records and gives data types
for column in df.columns:
    print(f"Value counts for {column}:")
    print(df[column].value_counts())
    print("\n")
# Out:
# Value counts for LB:
# LB
# 133.000000    129
# 130.000000    105
# 122.000000    103
# 138.000000     98
# 125.000000     87
#              ...
# 140.090770      1
# 123.159931      1
# 122.645790      1
# 136.142989      1
# 124.919186      1
# Name: count, Length: 153, dtype: int64
#
#
# Value counts for AC:
# AC
# 0.000000    833
# 0.000834     13
# 0.005838      9
# 0.002502      9
# 0.005004      9
#            ...
# 0.008006      1
# 0.012431      1
# 0.011986      1
# 0.003330      1
# 0.001616      1
# Name: count, Length: 1067, dtype: int64
#
#
# Value counts for FM:
# FM
#  0.000000    1232
#  0.000834      10
#  0.001668       9
#  0.003336       9
#  0.005838       7
#              ...
#  0.001229       1
#  0.028708       1
#  0.002894       1
# -0.000519       1
# -0.000188       1
# Name: count, Length: 776, dtype: int64
#
#
# Value counts for UC:
# UC
# 0.000000    318
# 0.000834     24
# 0.001668     15
# 0.002502     12
# 0.004170     10
#            ...
# ...

# %%
Key Insights from Value Counts
Baseline Fetal Heart Rate (LB):

The most frequent value for LB is 133.000000, occurring 129 times.
There are 153 unique values for LB, indicating a wide range of baseline heart rates.
Accelerations (AC):

The most frequent value for AC is 0.000000, occurring 833 times.
There are 1067 unique values for AC, indicating variability in accelerations during fetal monitoring.
Fetal Movements (FM):

The most frequent value for FM is 0.000000, occurring 1232 times.
There are 776 unique values for FM, indicating different levels of fetal movements recorded.
Uterine Contractions (UC):

The most frequent value for UC is 0.000000, occurring 318 times.
There are 1364 unique values for UC, indicating variability in uterine contractions.
Light Decelerations (DL):

The most frequent value for DL is 0.000000, occurring 1166 times.
There are 822 unique values for DL, indicating different levels of light decelerations recorded.
Severe Decelerations (DS):

The most frequent value for DS is 0.000000, occurring 1985 times.
There are 114 unique values for DS, indicating different levels of severe decelerations recorded.
Prolonged Decelerations (DP):

The most frequent value for DP is 0.000000, occurring 1821 times.
There are 264 unique values for DP, indicating different levels of prolonged decelerations recorded.
Percentage of Time with Abnormal Short-Term Variability (ASTV):

The most frequent value for ASTV is 65.000000, occurring 60 times.
There are 183 unique values for ASTV, indicating variability in abnormal short-term variability.
Mean Value of Short-Term Variability (MSTV):

The most frequent values for MSTV are 0.500000 and 0.800000, each occurring 116 times.
There are 165 unique values for MSTV, indicating variability in short-term variability.
Percentage of Time with Abnormal Long-Term Variability (ALTV):

The most frequent value for ALTV is 0.000000, occurring 1168 times.
There are 195 unique values for ALTV, indicating variability in abnormal long-term variability.
Mean Value of Long-Term Variability (MLTV):

The most frequent value for MLTV is 0.000000, occurring 124 times.
There are 351 unique values for MLTV, indicating variability in long-term variability.
Width of Baseline Fetal Heart Rate (Width):

The most frequent value for Width is 39.000000, occurring 42 times.
There are 261 unique values for Width, indicating variability in the width of baseline heart rate.
Tendency:

The most frequent value for Tendency is 0.000000, occurring 1037 times.
There are 111 unique values for Tendency, indicating different tendencies in the fetal heart rate.
Fetal Health Status (NSP):

The most frequent value for NSP is 1.000000, occurring 1546 times.
There are 111 unique values for NSP, indicating different fetal health statuses.
# Out:
#   Cell In[109], line 1
#     Key Insights from Value Counts
#         ^
# SyntaxError: invalid syntax

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
'''Interesting Findings 

Baseline FHR (LB):
Mean value is within the normal range, but extreme values suggest outliers which might represent anomalies or errors.

Accelerations (AC):
The mean value is very low, indicating infrequent accelerations which could be due to specific conditions or errors.

Fetal Movements (FM):
Significant number of outliers and high standard deviation indicate variability in fetal movements. Some extreme values suggest potential errors or unusual fetal activity.

Decelerations (DL, DS, DP):
Decelerations have very low mean values and many outliers, indicating infrequent but potentially significant decelerations.

Short Term and Long Term Variability (ASTV, MSTV, ALTV, MLTV):
Abnormal short-term variability (ASTV) is high, suggesting fetal distress.

Long-term variability (ALTV) also shows a wide range, indicating inconsistent fetal heart rate patterns.

NSP (Normal/Pathologic):
The high number of outliers suggests variability in the classification of normal/pathologic cases, which might require further investigation.

These findings can help in understanding fetal health and identifying any potential issues or anomalies in the dataset. 
'''
# Out:
# 'Interesting Findings \n\nBaseline FHR (LB):\nMean value is within the normal range, but extreme values suggest outliers which might represent anomalies or errors.\n\nAccelerations (AC):\nThe mean value is very low, indicating infrequent accelerations which could be due to specific conditions or errors.\n\nFetal Movements (FM):\nSignificant number of outliers and high standard deviation indicate variability in fetal movements. Some extreme values suggest potential errors or unusual fetal activity.\n\nDecelerations (DL, DS, DP):\nDecelerations have very low mean values and many outliers, indicating infrequent but potentially significant decelerations.\n\nShort Term and Long Term Variability (ASTV, MSTV, ALTV, MLTV):\nAbnormal short-term variability (ASTV) is high, suggesting fetal distress.\n\nLong-term variability (ALTV) also shows a wide range, indicating inconsistent fetal heart rate patterns.\n\nNSP (Normal/Pathologic):\nThe high number of outliers suggests variability in the clas
# ...

# %%
asc=df_imp.sort_values(by=['LB','AC','DS','DP','MLTV','Width','Tendency','NSP'],ascending=True)

# %%
print(asc)
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 1027   51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.000000
# 785    52.000000  0.000834  0.013344  0.000000  0.000000  0.000000  0.000000
# 134    52.000000  0.001590  0.000000  0.029851  0.000000  0.000000  0.000003
# 1834   52.188547  0.000000  0.001043  0.003128  0.007299  0.000000  0.000000
# 1664  106.000000  0.000000  0.000000  0.009472  0.000000  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 610   214.000000  0.002469  0.002469  0.002469  0.000000  0.000004  0.000000
# 1406  214.000000  0.005068  0.000000  0.001689  0.000000  0.000000  0.000000
# 612   214.000000  0.005181  0.012953  0.002591  0.000000  0.000000  0.000000
# 1504  214.000000  0.006189  0.000000  0.006189  0.000000  0.000000  0.000000
# 1103  214.000000  0.006972  0.000000  0.002960  0.000000  0.000000  0.000000
#
# ...

# %%
Q1=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].quantile(0.25)

# %%
Q1
# Out:
# LB          126.0
# AC            0.0
# DS            0.0
# DP            0.0
# MLTV          4.6
# Width        37.0
# Tendency      0.0
# NSP           1.0
# Name: 0.25, dtype: float64

# %%
Q2=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].quantile(0.50)

# %%
Q2
# Out:
# LB          133.000000
# AC            0.001634
# DS            0.000000
# DP            0.000000
# MLTV          7.400000
# Width        67.000000
# Tendency      0.000000
# NSP           1.000000
# Name: 0.5, dtype: float64

# %%
Q3=df[['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']].quantile(0.75)

# %%
Q3
# Out:
# LB          140.00000
# AC            0.00565
# DS            0.00000
# DP            0.00000
# MLTV         10.90000
# Width       100.00000
# Tendency      1.00000
# NSP           1.00000
# Name: 0.75, dtype: float64

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# LB          14.00000
# AC           0.00565
# DS           0.00000
# DP           0.00000
# MLTV         6.30000
# Width       63.00000
# Tendency     1.00000
# NSP          0.00000
# dtype: float64

# %%
UL=Q1+1.5*IQR
LL=Q3-1.5*IQR

# %%
columns_of_interest = ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']
limits_df = pd.DataFrame({
    'Column': columns_of_interest,
    'UL': UL.values,
    'LL': LL.values
})

# Combine UL and LL into a single tuple column
limits_df['Formatted'] = list(zip(limits_df['UL'], limits_df['LL']))

# Display the result
print(limits_df[['Column', 'Formatted']])
# Out:
#      Column                              Formatted
# 0        LB                         (147.0, 119.0)
# 1        AC  (0.008474577, -0.0028248590000000007)
# 2        DS                             (0.0, 0.0)
# 3        DP                             (0.0, 0.0)
# 4      MLTV            (14.05, 1.4499999999999993)
# 5     Width                           (131.5, 5.5)
# 6  Tendency                            (1.5, -0.5)
# 7       NSP                             (1.0, 1.0)

# %%
columns_of_interest = ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']
mask = pd.DataFrame()
for column in columns_of_interest:
    mask[column] = (df_imp[column] < LL[column]) | (df_imp[column] > UL[column])
    outliers = df_imp[mask.any(axis=1)]

print(outliers)
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# ...          ...       ...       ...       ...       ...           ...
# 2112  136.000000  0.000000  0.004823  0.006431  0.008039  9.488398e-07
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.000000e+00
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.000000e+00
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.000000e+00
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.000000e+00
#
#             DP  ASTV  MSTV  ALTV       MLTV  Width  Tendency       NSP
# ...

# %%
# for HISTOGRAMS
# Define columns of interest
columns_of_interest = ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']

# Plot the distribution for each column
for column in columns_of_interest:
    #plt.figure(figsize=(10, 6))
    sns.histplot(df_imp[column], kde=True,color='black')  # `histplot` is the updated function replacing `distplot`
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#for Scatter plots
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plots for pairs of columns
for i, column1 in enumerate(columns_of_interest):
    for column2 in columns_of_interest[i+1:]:
        plt.figure(figsize=(10, 6))
        plt.scatter(df_imp[column1], df_imp[column2], alpha=0.5,color='orange')
        plt.xlabel(column1)
        plt.ylabel(column2)
        plt.title(f'Scatter Plot of {column1} vs {column2}')
        plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
columns_of_interest = ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']

# Plot the distribution for each column
for column in columns_of_interest:
    #plt.figure(figsize=(10, 6))
    sns.boxplot(df_imp[column],color='black') 
    #plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pair plot to see relationships between variables
sns.pairplot(df_imp)
plt.show()
columns_to_plot = ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']
# Violin plots for deeper insights into the distribution of numerical variables
# Select a few relevant columns for the violin plots
columns_to_plot = df_imp.columns[:6]  # Adjust the slice to include relevant columns

for col in columns_to_plot:
    plt.figure(figsize=(10, 6))
    sns.violinplot(x=df_imp[col])
    plt.title(f'Violin Plot of {col}')
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df_imp.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.062839  0.018776 -0.166201 -0.126536 -0.005438
# AC       -0.062839  1.000000  0.009432  0.071863 -0.093196 -0.033101
# FM        0.018776  0.009432  1.000000 -0.053226  0.009718  0.029899
# UC       -0.166201  0.071863 -0.053226  1.000000  0.190128 -0.006922
# DL       -0.126536 -0.093196  0.009718  0.190128  1.000000  0.058430
# DS       -0.005438 -0.033101  0.029899 -0.006922  0.058430  1.000000
# DP       -0.047724 -0.083277  0.121274  0.070501  0.144940  0.004285
# ASTV      0.241857 -0.230439 -0.032691 -0.181161 -0.069361  0.008425
# MSTV     -0.169561  0.133649  0.017055  0.189406  0.410102  0.016077
# ALTV      0.210446 -0.271041 -0.011936 -0.227304 -0.186967 -0.004392
# MLTV     -0.003457 -0.104875 -0.006237 -0.049351 -0.165198  0.034349
# Width    -0.118425  0.234735  0.097204  0.107159  0.408664  0.040832
# Tendency  0.236864  0.031977 -0.018338 -0.066463 -0.023490 -0.015398
# ...

# %%
Key Insights:
Positive Correlations:

LB and ASTV: A positive correlation (0.241857) indicates that an increase in baseline fetal heart rate is associated with an increase in the percentage of abnormal short-term variability.
DL and MSTV: A high positive correlation (0.410102) suggests that as the duration of light sleep (DL) increases, the mean short-term variability (MSTV) also increases.
Negative Correlations:

LB and UC: A negative correlation (-0.166201) indicates that as the baseline fetal heart rate increases, uterine contractions (UC) decrease.
AC and ASTV: A significant negative correlation (-0.230439) suggests that higher accelerations (AC) are associated with lower percentages of abnormal short-term variability.
NSP (Fetal Health Status):

ASTV: A high positive correlation (0.421313) with NSP indicates that higher percentages of abnormal short-term variability are associated with suspect or pathological fetal health status.
ALTV: A positive correlation (0.365357) with NSP indicates that higher percentages of abnormal long-term variability are also associated with suspect or pathological fetal health status.
# Out:
#   Cell In[108], line 1
#     Key Insights:
#         ^
# SyntaxError: invalid syntax

# %%
INSIGHTS:
1. Understanding Fetal Health
Baseline Fetal Heart Rate (LB):

The average baseline fetal heart rate (LB) is an important indicator of fetal well-being. A normal range typically lies between 110 to 160 beats per minute. Our dataset's analysis showed most values within this range, indicating a generally healthy fetal population.
Recommendation: Continuous monitoring and regular check-ups for pregnant women to keep track of the baseline fetal heart rate.
Fetal Movement (FM):

Higher fetal movements (FM) are generally a sign of a healthy fetus. The analysis showed a positive correlation between fetal movements and other positive fetal health indicators.
Recommendation: Advise pregnant women to be aware of fetal movements and report any significant changes to healthcare providers.
2. Anomalies and Outliers
Outliers in Baseline Heart Rate:

Outliers in LB might indicate abnormal fetal conditions, such as hypoxia or other stress conditions.
Recommendation: Any significant deviations from the normal range should prompt immediate medical evaluation to prevent complications.
Fetal Distress Indicators:

Variables like 'ASTV' (percentage of time with abnormal short-term variability) and 'ALTV' (percentage of time with abnormal long-term variability) can indicate potential fetal distress.
Recommendation: Increased monitoring and possibly immediate intervention if high values in these parameters are observed.
3. Data Distribution and Trends
Distribution of Fetal Health Status (NSP):
The 'NSP' variable categorizes fetal health status into Normal, Suspect, and Pathological. The majority of the data points fall into the Normal category, but the presence of Suspect and Pathological cases indicates a need for vigilant monitoring.
Recommendation: Establish protocols for more frequent and detailed monitoring of cases falling into the Suspect and Pathological categories.
4. Advanced Visualizations
Violin Plots for Health Status:
Violin plots showed the distribution of heart rate variability and movements across different health statuses. Pathological cases typically had lower baseline variability and movement.
Recommendation: Use such visual tools in clinical settings to quickly identify high-risk pregnancies.

# %%
'''
The Cardiotocographic dataset offers valuable insights into fetal health monitoring. 
By identifying key indicators and their normal ranges, healthcare providers can better understand and predict fetal well-being. 
The use of advanced visualization techniques helps in identifying patterns and anomalies that may require immediate attention. 
Regular monitoring, combined with data-driven decision-making,can significantly improve prenatal care and outcomes.
'''
